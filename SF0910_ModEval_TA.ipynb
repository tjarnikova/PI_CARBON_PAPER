# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Figure description
#
#
# #### 5 subplots of model results vs observations for hindcast 201905 (only values where model>1800 are shown)
# #### a table of model statistics, both for full dataset and for

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import seawater
import netCDF4 as ncTA_WSS = np.zeros(5)
TA_RMSE = np.zeros(5)
TA_bias = np.zeros(5)
TA_modstd = np.zeros(5)
TA_obsstd = np.zeros(5)

TA_WSS_over1800 = np.zeros(5)
TA_RMSE_over1800 = np.zeros(5)
TA_bias_over1800 = np.zeros(5)
TA_modstd_over1800 = np.zeros(5)
TA_obsstd_over1800 = np.zeros(5)

# %% [markdown]
# #### LOAD OBSERVATIONAL DATA

# %%
infil = np.loadtxt('./Datasets/grl2016_nu.txt')
P = infil[:,8]
T = infil[:,9]
S = infil[:,10]
dic = infil[:,13]
alk = infil[:,15]
dens = seawater.dens(S,T,P)
# CONVERT FROM UMOL TO MMOL/M3
ta_conv=alk*dens/1000
dic_conv=dic*dens/1000

# %% [markdown]
# #### CALCULATE EVALUATION STATISTICS FOR YEARS 2013-2017

# %%
TA_WSS = np.zeros(5)
TA_RMSE = np.zeros(5)
TA_bias = np.zeros(5)
TA_modstd = np.zeros(5)
TA_obsstd = np.zeros(5)

TA_WSS_over1800 = np.zeros(5)
TA_RMSE_over1800 = np.zeros(5)
TA_bias_over1800 = np.zeros(5)
TA_modstd_over1800 = np.zeros(5)
TA_obsstd_over1800 = np.zeros(5)

for yr in range(2013,2018):
    index = yr - 2013

    scrdir = './MODEL_EVAL_scripts/'
    DIC = nc.Dataset(scrdir+'/DIC_hindcast201905_GRL_comp_' + str(yr) + '.nc')
    TA = nc.Dataset(scrdir+'/TA_hindcast201905_GRL_comp_' + str(yr) + '.nc')

    #extractions
    DIC_mod = DIC['model_output']['mod_point'][:]
    DIC_mod[DIC_mod==0]=np.nan
    dic_compbl = dic_conv[~(np.isnan(TA_mod))&(~np.isnan(ta_conv))]
    DIC_mod_compbl = DIC_mod[~(np.isnan(TA_mod))&(~np.isnan(ta_conv))]

    TA_mod = TA['model_output']['mod_point'][:]
    TA_mod[TA_mod==0]=np.nan
    TA_compbl = alk_conv[~(np.isnan(TA_mod))&(~np.isnan(ta_conv))]
    TA_mod_compbl = TA_mod[~(np.isnan(TA_mod))&(~np.isnan(ta_conv))]
    
    
    obs =TA_compbl
    mod = TA_mod_compbl
    xbar = np.mean(obs)
  
    TA_bias[index] = (-np.mean(obs) + np.mean(mod))
    TA_RMSE[index] = (np.sqrt(np.sum((mod - obs)**2) /len(obs)))
    TA_WSS[index] = (1-(np.sum((mod - obs)**2)  / np.sum((np.abs(mod - xbar) + np.abs(obs - xbar))**2)))
    TA_modstd[index] = np.std(mod)
    TA_obsstd[index] = np.std(obs)
    

    obs =TA_compbl[dic_compbl>1800]
    mod = TA_mod_compbl[dic_compbl>1800]
    xbar = np.mean(obs)

    TA_bias_over1800[index] = (-np.mean(obs) + np.mean(mod))
    TA_RMSE_over1800[index] = (np.sqrt(np.sum((mod - obs)**2) /len(obs)))
    TA_WSS_over1800[index] = (1-(np.sum((mod - obs)**2)  / np.sum((np.abs(mod - xbar) + np.abs(obs - xbar))**2)))
    TA_modstd_over1800[index] = np.std(mod)
    TA_obsstd_over1800[index] = np.std(obs)

# %%
# Out:
# [2210.92132423 2184.88853397 2177.45907677 2154.54246224 2128.18582466
#  2139.71376395 2130.30785458 2103.11943069 2091.24804049 2033.20622187
#  1973.87650568 2178.69635954 2148.12606564 2130.83781269 2115.22446036
#  2075.95827335 2064.78552112 2062.19454885 2073.06194847 2065.57419415
#  2151.33655737 2155.58629332 2136.54966422 2118.21453979 2101.98802996
#  2094.83396091 2062.04005596 1986.11580749 1906.43283794 1810.27338215
#  1738.93379243 2180.95102432 2161.27405238 2146.95485518 2140.59474094
#  2106.67343938 2106.29349309 2099.51607968 2004.83849556 1940.74368769
#  1819.69227714 1671.55645542 1463.97367267 2174.89693756 2184.27244566
#  2183.81868405 2158.12887424 2088.68500233 2136.49721895 2124.94164226
#  2040.85159565 2040.24899051 2027.71828309 1994.43894918 1972.00512594
#  2124.28652252 2091.12023893 2050.54604004 2024.43281297 1969.82745138
#  2043.1169304  2006.12539015 2045.0657788  1986.07677536 2008.34510251
#  2037.44995129 2260.83229849 2125.75129388 2321.84460173 2310.99056117
#  2284.85880444 2257.55541146 2238.27466804 2319.50731213 2283.84252604
#  2234.64088523 2172.27395701 2341.76656763 2330.37255954 2300.58123989
#  2273.04406607 2223.80041104 2309.61534575 2291.72285156 2252.04412186
#  2289.44557142 2228.64961022 2150.95572353 2159.86483464 2153.66323333
#  2135.44386808 2145.38930494 2141.18675582 2170.40016699 2318.99285782
#  2314.40526193 2230.25013986 2176.56218361 2155.04865077 2146.40266822
#  2132.27264727 2295.66444634 2226.09991576 2180.72431902 2130.31445454
#  2067.32569394 2054.46902592 2198.72360242 2175.43765921 2142.90255013
#  2151.24250592 2132.91041261 2122.21055247 2182.84891278 2139.48069169
#  2124.68147058 2108.51858552 2093.36823368 2075.44546055 1853.71767272
#  2171.59799601 2151.05703674 2125.45980216 2104.51699376 2076.6197957
#  2064.07039721 1961.5978877  2151.98320174 2143.37694731 2130.35934136
#  2081.24020481 2064.48679803 2076.28024816 2173.08831908 2145.9999648
#  2132.56804298 2089.38856382 2072.52802693 2072.23826558 2088.05281872
#  2256.44257393 2231.68986268 2166.91239727 2165.41581736 2126.92320466
#  2125.24688312 2280.90257544 2273.03509087 2270.5676141  2183.7757301
#  2206.44104484 2137.85711688 2113.34352017 2126.42089018 2070.35998832
#  2116.26027095 2028.9964851  2077.07025935 2077.5045754  2057.7572968
#  2038.31567393 1900.59131226 1117.7704535  2137.2485147  2099.44997073
#  2170.50985938 2133.70562373 2086.19969554 2084.41972905 2066.00364785
#  2012.27259143 1966.09387274 1705.25034984 1580.80636064 2218.79292515
#  2188.16873878 2173.19367904 2106.8945657  1975.93701429 2249.3734228
#  2215.01917538 2195.07805479 2178.02841577 2301.61634262 2293.39130062
#  2155.3488784  2106.91184142 2128.31144094 2320.05512734 2295.52314902
#  2202.09670907 2205.52048069 2160.45296198 2310.35431294 2312.69022953
#  2233.11991545 2213.90336592 2178.3515601  2216.90565206 2155.81677454
#  2149.76076285 2124.36504042 2079.1548981  1887.51566436 2188.09224501
#  2167.80412059 2125.26081683 2056.6656325  2188.94597808 2170.05659413
#  2154.48308882 2095.47870312 1883.57167607 2216.00325674 2194.81569698
#  2204.89624887 2162.97302563 2125.88534224 2117.08894279 2079.86872648
#  2055.21847454 2157.7348487  2138.20764491 2113.95697017 2059.96499916
#  2045.52869576 2009.80310801 1905.42861275 2120.94289644 2147.86949446
#  2107.50080144 2087.75150923 2045.61021706 1982.00753317 1850.03937541
#  2165.47283076 2110.77917071 2082.0161293  2072.77261307 1767.61965791
#  2173.18093308 2157.47022624 2129.66679214 2083.94752059 2074.12160753
#  2034.00042059 1101.88733018 2343.97808306 2340.62479613 2303.43861142
#  2272.81518447 2222.43475206 2179.11801742 2169.94689601 2327.24119582
#  2310.01870565 2222.16142779 2187.07792234 2163.46039191 2145.43931558
#  2280.71922882 2267.48620968 2194.0995158  2140.7773726  2121.08530738
#  2092.90598202 2241.49777558 2212.474822   2124.92641189 2102.60505718
#  2100.62067737 2324.38521653 2260.72062619 2336.37339862 2233.73870875
#  2191.77469283 2188.79049736 2161.83409616 2171.35713983 2106.80124589
#  2078.85196182 2178.63696754 2106.16450902 2106.19649195 2060.87665711
#  1855.59785246 2175.86315452 2204.52799276 2104.91406343 2060.37419172
#  2159.30652537 2112.36623262 2073.84352304 2007.51569352 2042.77114867
#  1958.68112126 2001.94389819 1991.68496845 2234.30846277 2199.10429512
#  2174.7119834  2051.9490753  2072.01391514 2056.71948725 2316.73116498
#  2331.5152391  2301.64349692 2200.58881169 2152.95514702 2143.46037683
#  2185.79893774 2195.25588368 2157.03969059 2158.70073752 2112.67784415
#  2088.87807406 2073.29320189 1998.46387367 1909.59707832 1797.39569078
#  2077.0896549  2063.96363492 2024.33647745 2015.4929069  1946.21128309
#  1866.0106366  1764.29744331 2127.35511588 2139.41754355 2124.24723637
#  2075.14341483 2066.34065565 2036.27894751 2009.10485449 1934.60742509
#  1846.7599848  1858.02678099 2149.88815072 2126.37842616 2096.59210906
#  2017.04276726 2005.90230497 2025.70036685 2173.8653402  2172.33234851
#  2153.59083515 2129.62649705 2114.97217098 2110.45001335 2096.40756002
#  2072.73600714 2048.15590256 1997.39362905 1976.89622523 1965.25910003
#  2147.56672097 2166.762814   2140.12888819 2121.92423204 2109.03900132
#  1888.1530809  1227.87398666 2151.8376189  2127.88437109 2098.55410912
#  2104.63102475 2066.06006088 2217.33340154 1937.22301191 1779.06552012
#  1681.22664224 2174.87115035 2173.06052885 2165.52939851 2143.20604916
#  2082.74801944 2076.54233738 2072.29505868 2058.89129933 2050.8672784
#  2050.24710817 2045.89880199 2047.31758797 2185.54825618 2189.16942307
#  2147.4933445  2144.39693141 2125.50277975 2121.74866238 2136.52791864
#  2083.39206391 2095.24775819 2071.27158453 2088.36841498 2072.33973516
#  2153.68321201 2155.7606616  2135.6957228  2293.31809339 2103.32067324
#  2208.17426341 2175.20114308 2170.11945281 2153.09698719 2127.33220669
#  2113.96745029 2072.90585239 2174.97938704 2164.95822781 2195.37798417
#  2178.92470945 2174.59985365 2126.21630297 2077.2315893  2051.44999991
#  2053.3348764  2022.38900945 2018.13933306 2023.44318106 2192.54668314
#  2185.00652514 2176.93315931 2161.0849281  2161.56817945 2155.08280864
#  2122.70183511 2099.95817925 2072.89171365 1976.72909145 1500.56787699
#  2170.19185644 2169.00393107 2168.4385103  2169.40198535 2167.12382219
#  2158.5221608  2145.69984863 2133.64311926 2124.21336964 2128.76848461
#  2125.83493254 2109.04978122 2085.13700187 2082.01010933 2065.68447913
#  2048.22947489 1980.44355397 1988.08695174 1972.02726745 1703.6081537
#  2323.59460196 2326.72465824 2330.02947853 2326.54055127 2324.34007176
#  2320.92616618 2293.65050506 2261.87449234 2250.16146422 2252.78562667
#  2274.4780889  2246.08062835 2238.69621486 2231.63956422 2237.6552299 ]

# %%
print(TA_bias)
# Out:
# [26.738551   29.90359006 27.86892209 28.00881467 27.35525022]

# %%
fig = plt.figure(figsize=(13,8))
fs = 12

for yr in range(2013,2018):
    i = yr - 2012
    scrdir = './MODEL_EVAL_scripts/'
    TA = nc.Dataset(scrdir+'/TA_hindcast201905_GRL_comp_' + str(yr) + '.nc')

    #extractions

    TA_mod = TA['model_output']['mod_point'][:]
    is_ref = TA['model_output']['mod_x'][:]
    js_ref = TA['model_output']['mod_y'][:]


    #locations 
    loc_tag = np.zeros_like(TA_mod)
    loc_tag[:] = 4

    for w in range(0,len(loc_tag)):
        x = is_ref[w]
        y = js_ref[w]
        #jdf is 1
        if  (x <200) & (y>220) & (y<500) :
            loc_tag[w] = 1
            #n strait
        if  (y >= 550):
            loc_tag[w] = 2
            #central strait
        if (x> 150) & (y>380) & (y<550):
            loc_tag[w] = 3
            #4 is haro/puget
        if ((x>150) & (y>320) & (y<370)):
            loc_tag[w] =4

    TA_mod[TA_mod==0]=np.nan

    #TA
    TA_jdf=ta_conv[~(np.isnan(TA_mod))&(loc_tag==1)]
    TA_haro=ta_conv[~(np.isnan(TA_mod))&(loc_tag==4)]
    TA_ns =ta_conv[~(np.isnan(TA_mod))&(loc_tag==2)]
    TA_cs=ta_conv[~(np.isnan(TA_mod))&(loc_tag==3)]

    TA_MODjdf=TA_mod[~(np.isnan(TA_mod))&(loc_tag==1)]
    TA_MODharo=TA_mod[~(np.isnan(TA_mod))&(loc_tag==4)]
    TA_MODns =TA_mod[~(np.isnan(TA_mod))&(loc_tag==2)]
    TA_MODcs=TA_mod[~(np.isnan(TA_mod))&(loc_tag==3)]

    TA_compbl = ta_conv[~(np.isnan(TA_mod))]
    TA_mod_compbl = TA_mod[~(np.isnan(TA_mod))]

    #plot

    ax = fig.add_subplot(2,3,i)
    ax.grid(color='k', linestyle=':', linewidth=1)
    ax.plot(TA_jdf,TA_MODjdf,'ko',markersize=5, label = 'Juan de Fuca')
    ax.plot(TA_haro,TA_MODharo,c='fuchsia', marker='o',linestyle='None',markersize=5, label = 'Haro Strait')
    ax.plot(TA_ns,TA_MODns,c='orange', marker='o',linestyle='None',markersize=5, label = 'Northern Strait')
    ax.plot(TA_cs,TA_MODcs,c='green', marker='o',linestyle='None',markersize=5, label = 'Central Strait')

    ax.set_xlabel('observations (mmol $m^{-3}$)', fontsize = fs)
    ax.set_ylabel('model (mmol $m^{-3}$)', fontsize = fs)
    ax.set_title('year' + str(yr))
    #ax.legend( ['Juan de Fuca','Haro Strait','Northern Strait','Central Strait'],loc='best', fontsize = 20)
    if yr == 2017:
        plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set_xlim(1800,2350)
    ax.set_ylim(1800,2350)
    ax.plot([1800,2400],[1800,2400],'k')

    plt.title(str(yr), fontsize = 16)
    
plt.suptitle('TA model evaluation, years 2013-2017', y = 1.05, fontsize = 20)

plt.tight_layout()

# %% [markdown]
# #### PUT SKILL METRICS IN ARRAY FOR PLOTTING, CONVERT TABLE TO LIST AND PLOT

# %%
#matrix of evaluation metrics
tablemat = np.zeros([5,3])
tablemat[:,0] = TA_bias
tablemat[:,1] = TA_RMSE
tablemat[:,2] = TA_WSS


tablelist = np.zeros([5,3])
np.ndarray.tolist(tablelist)

#list of evaluation metrics
for i in range(0,len(tablelist)):
    for j in range(0,len(tablelist[i])):
        tablelist[i,j] = '%s' % float('%.3g' % tablemat[i,j]) # ('{:.3f}'.format(tablemat[i,j]))

tablemat_over1800 = np.zeros([5,3])
tablemat_over1800[:,0] = TA_bias_over1800
tablemat_over1800[:,1] = TA_RMSE_over1800
tablemat_over1800[:,2] = TA_WSS_over1800


tablelist_over1800 = np.zeros([5,3])
np.ndarray.tolist(tablelist_over1800)

#list of evaluation metrics
for i in range(0,len(tablelist_over1800)):
    for j in range(0,len(tablelist_over1800[i])):
        tablelist_over1800[i,j] = '%s' % float('%.3g' % tablemat_over1800[i,j]) # ('{:.3f}'.format(tablemat[i,j]))

# %%
fig = plt.figure()
fig = plt.figure(figsize=(10,4))
ax = fig.add_subplot(121)
fs = 10
sc1 = 2.5
sc2 = 2.5
y = [1, 2, 3, 4, 5, 4, 3, 2, 1, 1, 1, 1, 1, 1, 1, 1]    
col_labels = ['bias\n (mmol $m^{-3}$)', 'RMSE\n (mmol $m^{-3}$)', 'WSS']
row_labels = ['2013', '2014', '2015','2016','2017']
table_vals = [[11, 12, 13], [21, 22, 23], [31, 32, 33],[21, 22, 23],[21, 22, 23]]



# Draw table
the_table = plt.table(cellText=tablelist,
                      colWidths=[0.1] * 3,
                      rowLabels=row_labels,
                      colLabels=col_labels,
                      loc='center')
the_table.auto_set_font_size(False)
the_table.set_fontsize(fs)
the_table.scale(sc1, sc2)

# Removing ticks and spines enables you to get the figure only with table
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', right=False, left=False, labelleft=False)
for pos in ['right','top','bottom','left']:
    plt.gca().spines[pos].set_visible(False)
    
plt.title('Model Evaluation Metrics \n (all TA observations)')
    
ax = fig.add_subplot(122)
y = [1, 2, 3, 4, 5, 4, 3, 2, 1, 1, 1, 1, 1, 1, 1, 1]    
col_labels = ['bias \n (mmol $m^{-3}$)', 'RMSE\n (mmol $m^{-3}$)', 'WSS']
row_labels = ['2013', '2014', '2015','2016','2017']
table_vals = [[11, 12, 13], [21, 22, 23], [31, 32, 33],[21, 22, 23],[21, 22, 23]]

# Draw table
the_table = plt.table(cellText=tablelist_over1800,
                      colWidths=[0.1] * 3,
                      rowLabels=row_labels,
                      colLabels=col_labels,
                      loc='center')
the_table.auto_set_font_size(False)
the_table.set_fontsize(fs)
the_table.scale(sc1, sc2)
plt.title('Model Evaluation Metrics \n (TA observations where DIC > 1800 (mmol $m^{-3}$))')
# Removing ticks and spines enables you to get the figure only with table
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.tick_params(axis='y', which='both', right=False, left=False, labelleft=False)
for pos in ['right','top','bottom','left']:
    plt.gca().spines[pos].set_visible(False)

plt.tight_layout()

# %%
print('Mean bias: '+str(np.mean(TA_bias)))
print('Mean RMSE: '+str(np.mean(TA_RMSE)))
print('Mean WSS: '+str(np.mean(TA_WSS)))
print()
print('Mean bias over 1800: '+str(np.mean(TA_bias_over1800)))
print('Mean RMSE over 1800: '+str(np.mean(TA_RMSE_over1800)))
print('Mean WSS over 1800: '+str(np.mean(TA_WSS_over1800)))
# Out:
# Mean bias: 27.97502560726307
# Mean RMSE: 80.8739111947122
# Mean WSS: 0.8860666692619417
#
# Mean bias over 1800: 16.836313893016904
# Mean RMSE over 1800: 46.7832310874048
# Mean WSS over 1800: 0.9211239261695399
